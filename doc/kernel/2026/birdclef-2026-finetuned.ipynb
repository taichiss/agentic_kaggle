# %%
import os, sys, subprocess, pandas as pd

bundle_dir = "/kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010"
ckpt_path = f"{bundle_dir}/checkpoint.pth"
adapter_path = f"{bundle_dir}/perch_adapter.pth"

competition_dir = "/kaggle/input/competitions/birdclef-2026"
if not os.path.exists(competition_dir):
    competition_dir = "/kaggle/input/birdclef-2026"

model_dir = "/kaggle/input/models/google/bird-vocalization-classifier/tensorflow2/perch_v2_cpu/1"

onnx_path = "/kaggle/input/datasets/rishikeshjani/perch-onnx-for-birdclef-2026/perch_v2_ir9.onnx"
if not os.path.exists(onnx_path):
    onnx_path = "/kaggle/input/datasets/rishikeshjani/perch-onnx-for-birdclef-2026/perch_v2.onnx"

extra_cache_dirs = "/kaggle/input/datasets/jaejohn/perch-meta"

print("bundle:", os.path.exists(bundle_dir))
print("ckpt:", os.path.exists(ckpt_path))
print("adapter:", os.path.exists(adapter_path))
print("competition:", os.path.exists(competition_dir))
print("model:", os.path.exists(model_dir))
print("onnx:", os.path.exists(onnx_path))
print("cache:", os.path.exists(extra_cache_dirs))

cmd = [
    sys.executable, f"{bundle_dir}/scripts/infer_pt.py",
    "--checkpoint", ckpt_path,
    "--perch-adapter", adapter_path,
    "--perch-adapter-weight", "0.2",
    "--base", competition_dir,
    "--model-dir", model_dir,
    "--onnx-path", onnx_path,
    "--extra-cache-dirs", extra_cache_dirs,
    "--output", "/kaggle/working/submission.csv",
]

print("Running:", " ".join(cmd))
subprocess.run(cmd, check=True)

sub = pd.read_csv("/kaggle/working/submission.csv")
print("submission shape:", sub.shape)
display(sub.head(3))
# Out:
# bundle: True
# ckpt: True
# adapter: True
# competition: True
# model: True
# onnx: True
# cache: True
# Running: /usr/bin/python3 /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/scripts/infer_pt.py --checkpoint /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/checkpoint.pth --perch-adapter /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/perch_adapter.pth --perch-adapter-weight 0.2 --base /kaggle/input/competitions/birdclef-2026 --model-dir /kaggle/input/models/google/bird-vocalization-classifier/tensorflow2/perch_v2_cpu/1 --onnx-path /kaggle/input/datasets/rishikeshjani/perch-onnx-for-birdclef-2026/perch_v2.onnx --extra-cache-dirs /kaggle/input/datasets/jaejohn/perch-meta --output /kaggle/working/submission.csv
# 2026-04-26 09:47:59.602334: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777196879.910181      43 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777196880.004318      43 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777196880.812599      43 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777196880.812742      43 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777196880.812751      43 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777196880.812757      43 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-26 09:48:32.375604: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ONNX Runtime installed from /kaggle/input/datasets/rishikeshjani/perch-onnx-for-birdclef-2026/onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# ONNX Runtime available
# TensorFlow already available; skip local wheel install
# MODE = submit
# USE_GPU = True
# V18 CFG loaded
#   n_epochs=40  patience=8  oof_n_splits=3  mlp_max_iter=200
#   seed=42
#   perch_adapter_ckpt=/kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/perch_adapter.pth (weight=0.2)
# Config ready
#   run_oof=False  verbose=False  dryrun=0
#   BASE=/kaggle/input/competitions/birdclef-2026
#   MODEL_DIR=/kaggle/input/models/google/bird-vocalization-classifier/tensorflow2/perch_v2_cpu/1
#   WORK_DIR=/kaggle/working/cache
#   SUBMISSION_PATH=/kaggle/working/submission.csv
# TUNE: proto=40ep/8pat@0.001 (d_model=128,d_state=16,layers=2,heads=2) res=30ep/8pat@0.001 (d_model=64,d_state=8) ens_w=0.5 mlp(min_pos=5,pca=64,alpha=0.4,hidden=(128,64),max_iter=300) calib(min_pos_files=3,default_t=0.5) tta(shifts=[0, 1, -1, 2, -2])
# TUNE: calibration uses OOF probs when available via BC26_CALIB_USE_OOF=1
# Classes: 234 | Fully-labeled files: 59
# Full-file windows: 708 | Active classes: 71
# Using ONNX Perch (150x faster) | providers=['CPUExecutionProvider']
# Mapped: 203 / 234 species have a Perch logit
# Unmapped species total:        31
# Species with genus proxy:      3
# Species still without signal:  28
#
# Proxy targets:
#   1491113      (Amphibia  ) ->9 Perch genus matches
#   1595929      (Amphibia  ) ->2 Perch genus matches
#   25073        (Amphibia  ) ->6 Perch genus matches
# [OK] Perch inference engine (ONNX + multithreaded I/O) defined
# USE_ONNX = True  (cache will be built with ONNX)
# Using external cache: /kaggle/input/datasets/jaejohn/perch-meta
# Loading Perch cache from: /kaggle/input/datasets/jaejohn/perch-meta
#   npz keys      : ['scores_full_raw', 'emb_full']
#   parquet cols  : ['row_id', 'filename', 'site', 'hour_utc']
#   scores ->'scores_full_raw'  shape=(708, 234)
#   embs   ->'emb_full'  shape=(708, 1536)
# sc_tr: (708, 234)  emb_tr: (708, 1536)  Y_FULL_aligned: (708, 234)
# [OK] Temporal smoothing helper defined
# [OK] Prior table functions defined
# [OK] File-level confidence scaling defined
# [OK] Temperatures: 171 event species (T=1.10), 63 texture species (T=0.95)
# [OK] CHANGE 1: Upgraded MLP probe (pca_dim=64, hidden=(128,64), max_iter=300, min_pos=5)
# Torch device: cpu
# [OK] Loaded Perch adapter: /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/perch_adapter.pth (arch=mlp2_legacy, hidden=640, hidden2=320, emb_dim=1536, weight=0.2)
# [OK] Applied Perch adapter to training cache in 0.1s | score range [-7.920, 11.740]
# [OK] Vectorized MLP probe inference defined
# [OK] CHANGE 2: Isotonic calibration + per-class threshold optimization defined
# [OK] Rank-aware scaling defined
# [OK] Adaptive delta smoothing defined
# [OK] CHANGE 4: LightProtoSSM with cross-attention (2 heads) defined
# [OK] CHANGE 3: TTA with 5 circular shifts defined
# [OK] ResidualSSM defined (~439K params, ~20s training)
# Submit mode: skipping OOF evaluation
# No hidden test -dry-run on 20 train files
# Test scores: (240, 234)
# [OK] Applied Perch adapter to test scores in 0.0s | score range [-8.079, 11.740]
# Loading pipeline checkpoint: /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/checkpoint.pth
# Checkpoint loaded: probes=63 | n_sites_cap=20 | alpha_blend=0.400 | ensemble=bagging(5) | proto_arch(d_model=128,d_state=16,layers=2,heads=2) | res_arch(d_model=64,d_state=8)
# [INFO] Bagging fold 1/5 test inference done
# [INFO] Bagging fold 2/5 test inference done
# [INFO] Bagging fold 3/5 test inference done
# [INFO] Bagging fold 4/5 test inference done
# [INFO] Bagging fold 5/5 test inference done
# [INFO] Using bagged first-pass logits from 5 folds
# Correction applied -mean_abs=0.1287  score range [-6.803, 8.412]
#
# /kaggle/working/submission.csv saved -shape (240, 235)
# Total wall time: 1.2 min
# Running: /usr/bin/python3 /kaggle/input/datasets/gerarddevlin/bundle13/kaggle_bundle_v52_bag5_s44_rw010/scripts/two_pass_ssm_pipeline_v2.py
# submission shape: (240, 235)
#                                      row_id   1161364    116570   1176823  \
# 0   BC2026_Train_0001_S08_20250606_030007_5  0.091161  0.383850  0.024106
# 1  BC2026_Train_0001_S08_20250606_030007_10  0.109653  0.391877  0.019743
# 2  BC2026_Train_0001_S08_20250606_030007_15  0.105203  0.380610  0.022895
#
#     1491113   1595929    209233     22930     22956     22961  ...   whnjay1  \
# 0  0.049171  0.000074  0.188660  0.011601  0.031843  0.002995  ...  0.057233
# 1  0.048023  0.000058  0.195976  0.010009  0.035751  0.002500  ...  0.075419
# 2  0.047516  0.000067  0.185322  0.011073  0.029448  0.002926  ...  0.080368
#
#      whtdov   whwpic1    y00678    yebcar   yebela1    yecmac    yecpar  \
# 0  0.540170  0.215583  0.197007  0.056247  0.598936  0.067363  0.057108
# 1  0.519689  0.293080  0.225714  0.029670  0.443527  0.073520  0.053978
# 2  0.523988  0.258059  0.230228  0.037722  0.555180  0.075316  0.061656
#
#     yehcar1   yeofly1
# 0  0.283666  0.563126
# 1  0.337296  0.541025
# 2  0.315951  0.432218
#
# [3 rows x 235 columns]
